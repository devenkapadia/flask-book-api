# %%
import numpy as np
import pandas as pd

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
books = pd.read_csv('books.csv')
users = pd.read_csv('users.csv')
ratings = pd.read_csv('ratings.csv')

# %%
books['Image-URL-M'][1]
# Out:
# 'http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg'

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
dataframe = ratings.merge(books,on='ISBN')

# %%
dataframe = dataframe[dataframe['Book-Rating']!=0]

# %%
dataframe
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1           2313  034545104X            5
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# 9          50403  034545104X            9
# 13         63970  034545104X            8
# ...          ...         ...          ...
# 1031123   276681  1931333246           10
# 1031124   276683  0316185922            5
# 1031127   276688  0312264186            8
# 1031132   276688  1575660792            7
# 1031135   276704  0806917695            5
#
#                                                 Book-Title       Book-Author  \
# 1                                     Flesh Tones: A Novel        M. J. Rose
# 3                                     Flesh Tones: A Novel        M. J. Rose
# 4                                     Flesh Tones: A Novel        M. J. Rose
# 9                                     Flesh Tones: A Novel        M. J. Rose
# ...

# %%
df_new = dataframe.drop_duplicates(subset=['ISBN', 'Book-Title'])

# %%
df_new
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1           2313  034545104X            5
# 60        276726  0155061224            5
# 66          7158  0446520802           10
# 178       276729  052165615X            3
# 179       276729  0521795028            6
# ...          ...         ...          ...
# 1031123   276681  1931333246           10
# 1031124   276683  0316185922            5
# 1031127   276688  0312264186            8
# 1031132   276688  1575660792            7
# 1031135   276704  0806917695            5
#
#                                                 Book-Title       Book-Author  \
# 1                                     Flesh Tones: A Novel        M. J. Rose
# 60                                        Rites of Passage        Judith Rae
# 66                                            The Notebook   Nicholas Sparks
# 178                                         Help!: Level 1     Philip Prowse
# ...

# %%
author_book_counts = df_new['Book-Author'].value_counts()

# %%
df_author = author_book_counts[author_book_counts > 6].index

# %%
df_author
# Out:
# Index(['Stephen King', 'Agatha Christie', 'William Shakespeare',
#        'Barbara Cartland', 'Nora Roberts', 'Terry Pratchett', 'Isaac Asimov',
#        'Charles Dickens', 'Carolyn Keene', 'Ann M. Martin',
#        ...
#        'Gwynne Forster', 'Dafydd ab Hugh', 'Lawrence Schiller',
#        'Gregory J. P. Godek', 'Jill McGown', 'Yasmina Khadra',
#        'Elizabeth Enright', 'Tony Kushner', 'Natalie Goldberg',
#        'Ellery Queen'],
#       dtype='object', length=3427)

# %%
filtered_books = df_new[df_new['Book-Author'].isin(df_author)]

# %%
filtered_books
# Out:
#          User-ID        ISBN  Book-Rating  \
# 66          7158  0446520802           10
# 181       192101  2080674722            7
# 183       276744  038550120X            7
# 370         2288  0425115801           10
# 614         1660  0553561618            6
# ...          ...         ...          ...
# 1031046   276579  0307626458            6
# 1031051   276579  0590762648            6
# 1031108   276680  0671516949            7
# 1031109   276680  067179387X            9
# 1031135   276704  0806917695            5
#
#                                                 Book-Title  \
# 66                                            The Notebook
# 181                            Les Particules Elementaires
# 183                                        A Painted House
# 370                                              Lightning
# 614                                          Dark Paradise
# ...                                                    ...
# ...

# %%
author_avg_ratings = filtered_books.groupby('Book-Author')['Book-Rating'].mean().sort_values(ascending=False).reset_index()
top_100_authors = author_avg_ratings.head(100)['Book-Author'].tolist()

# %%
top_100_authors
# Out:
# ['Maki Murakami',
#  'Anne Bishop',
#  'Wataru Yoshizumi',
#  'Takehiko Inoue',
#  'Michiro Ueyama',
#  'Emanuel Swedenborg',
#  'Terri Farley',
#  'Kevin Smith',
#  'Simon Furman',
#  'Daisaku Ikeda',
#  'Helene Siegel',
#  'Penny Frank',
#  'Gerhard Gruitrooy',
#  'Neesa Hart',
#  'Mitsumasa Anno',
#  'Shel Silverstein',
#  'Maud Hart Lovelace',
#  'Jonathan Pearce',
#  'Patricia Thayer',
#  'Editors of Phaidon Press',
#  'Judd Winick',
#  'LURLENE MCDANIEL',
#  'Robert Stanek',
#  'Ted Smart',
#  'Graeme Base',
#  'Robert Sabuda',
#  'Rick Kirkman',
#  'David Attenborough',
#  'Tony Abbott',
#  'Yu Watase',
#  'Soren Kierkegaard',
#  'Kathie Denosky',
#  'Dougal Dixon',
#  'Andrew Lang',
#  'Don Coldsmith',
#  'Ronda Thompson',
#  'Sanami Matoh',
#  'Marcia Willett',
#  'Mary Oliver',
#  'Ken Akamatsu',
#  'Winston Graham',
#  'A.A. Milne',
#  'Raymond Briggs',
#  'Clement Clarke Moore',
#  'J.R.R. TOLKIEN',
#  'Hayao Miyazaki',
#  'Walt Disney Company',
#  'Jeanie London',
# ...

# %%
def get_top_books(author):
    author_books = df_new[df_new['Book-Author']==author]
    top_books = author_books.sort_values(by='Book-Rating', ascending=False).head(5)
    top_books_list = top_books.to_dict(orient='records')
    
    print(top_books_list)

# %%
get_top_books('Stephen King')
# Out:
# [{'User-ID': 26756, 'ISBN': '0451178599', 'Book-Rating': 10, 'Book-Title': 'Needful Things', 'Book-Author': 'Stephen King', 'Year-Of-Publication': 1993, 'Publisher': 'New Amer Library', 'Image-URL-S': 'http://images.amazon.com/images/P/0451178599.01.THUMBZZZ.jpg', 'Image-URL-M': 'http://images.amazon.com/images/P/0451178599.01.MZZZZZZZ.jpg', 'Image-URL-L': 'http://images.amazon.com/images/P/0451178599.01.LZZZZZZZ.jpg'}, {'User-ID': 13082, 'ISBN': '0451151259', 'Book-Rating': 10, 'Book-Title': 'Eyes of the Dragon', 'Book-Author': 'Stephen King', 'Year-Of-Publication': 1988, 'Publisher': 'Penguin Putnam~mass', 'Image-URL-S': 'http://images.amazon.com/images/P/0451151259.01.THUMBZZZ.jpg', 'Image-URL-M': 'http://images.amazon.com/images/P/0451151259.01.MZZZZZZZ.jpg', 'Image-URL-L': 'http://images.amazon.com/images/P/0451151259.01.LZZZZZZZ.jpg'}, {'User-ID': 86683, 'ISBN': '8484503151', 'Book-Rating': 10, 'Book-Title': 'Un Saco de Huesos', 'Book-Author': 'Stephen King', 'Year-Of-Publicati
# ...

# %%
import pickle
pickle.dump(df_new,open('authors.pkl','wb'))

# %% [markdown]
# ## Popularity Based Recommender System

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# ...

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(50)

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_rating']]

# %%
popular_df['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'

# %% [markdown]
# ## Collaborative Filtering Based Recommender System

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
padhe_likhe_users = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(padhe_likhe_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg']]

# %%
pt.index[545]
# Out:
# "The Handmaid's Tale"

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
books.drop_duplicates('Book-Title')
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271354  0449906736      Flashpoints: Promise and Peril in a New World
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
pip show numpy
# Out:
# Name: numpy
# Version: 1.20.3
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License: BSD
# Location: c:\users\deven\anaconda3\lib\site-packages
# Requires:
# Required-by: ydata-profiling, wordcloud, vispy, visions, tifffile, tables, statsmodels, seaborn, scipy, scikit-learn, scikit-image, PyWavelets, pyerfa, phik, patsy, pandas, numexpr, numba, mpl-scatter-density, mkl-random, mkl-fft, missingno, matplotlib, imageio, ImageHash, imagecodecs, h5py, glue-vispy-viewers, glue-core, gensim, fast-histogram, echo, daal4py, Bottleneck, bokeh, bkcharts, astropy
# Note: you may need to restart the kernel to use updated packages.
